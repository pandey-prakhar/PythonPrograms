# %%
from PIL import Image, ImageFilter, ImageDraw
from matplotlib.pyplot import imshow

# %%
fl='myfig.jpg'
fn=Image.open(fl)
imshow(fn)

# %%
print(fn.size)
print(fn.format_description)
print(fn.mode)
# Out:
# (2557, 3155)
# JPEG (ISO 10918)
# RGB

# %%
rfn=fn.resize((270,350))
imshow(rfn)
